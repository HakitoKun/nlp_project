# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import numpy as np

# %%
with open('trainer_state.json') as f:
    data = json.load(f)

# %%
data['log_history'][20]['loss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-cd27c182883d> in <module>
# ----> 1 data['log_history'][20]['loss']
#
# KeyError: 'loss'

# %%
train_loss = []
train_steps = []

eval_loss = []
eval_rouge1 = []
eval_rouge2 = []
eval_rougeL = []
eval_rougeLsum = []

# %%
loss_rouge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-20a239dee410> in <module>
# ----> 1 loss_rouge
#
# NameError: name 'loss_rouge' is not defined

# %%
j = 0
for i in data['log_history']:
    try:
        train_loss.append(i['loss'])
        train_steps.append(i['step'])
    except Exception:
        eval_loss.append([i['step'], i['eval_rouge1']])
        eval_rouge1.append([i['step'], i['eval_rouge1']])
        eval_rouge2.append([i['step'], i['eval_rouge2']])
        eval_rougeL.append([i['step'], i['eval_rougeL']])
        eval_rougeLsum.append([i['step'], i['eval_rougeLsum']])
        pass

# %%
plt.plot(train_steps, train_loss)

# %%
# Train Loss vs EvalLoss
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(train_steps, train_loss)
ax.plot(*zip(*eval_loss))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['Train Loss', 'eval_loss'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_loss")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_loss')

# %%
# Train Loss vs RougeLSum
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(train_steps, train_loss)
ax.plot(*zip(*eval_rouge1))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['Train Loss', 'eval_rouge1'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_rouge1")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_rouge1')

# %%
# Train Loss vs Rouge2
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(train_steps, train_loss)
ax.plot(*zip(*eval_rouge2))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['Train Loss', 'eval_rouge2'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_rouge2")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_rouge2')

# %%
# Train Loss vs RougeL
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(train_steps, train_loss)
ax.plot(*zip(*eval_rougeL))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['Train Loss', 'eval_rougeL'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_rougeL")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_rougeL')

# %%
# Train Loss vs RougeLSum
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(train_steps, train_loss)
ax.plot(*zip(*eval_rougeLsum))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['Train Loss', 'eval_rougeLsum'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_rougeLsum")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_rougeLsum')

# %%
# Train Loss vs RougeLSum
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(eval_rouge1, eval_rouge2)
#ax.plot(*zip(*eval_rouge1))
ax.xaxis.set_major_locator(plt.MaxNLocator(7))
ax.legend(['eval_rouge1', 'eval_rouge2'])
ax.set_xlabel("Steps")
ax.set_ylabel("Value Loss")
ax.set_title("Train Loss VS eval_rouge1")
# Out:
# Text(0.5, 1.0, 'Train Loss VS eval_rouge1')

# %%
plt.scatter(np.array(eval_rouge1)[:,1], np.array(eval_rouge2)[:,1])

# %%
eval_rouge1
# Out:
# [[10000, 18.2913],
#  [20000, 18.3623],
#  [30000, 18.2787],
#  [40000, 18.5158],
#  [50000, 18.5973],
#  [60000, 18.3853],
#  [70000, 18.6932],
#  [80000, 18.7274],
#  [90000, 18.5234],
#  [100000, 18.5842],
#  [110000, 18.5583]]

# %%
np.
